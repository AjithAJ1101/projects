# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
test=pd.read_csv('test-1617360461595-1660719701431.csv')

# %%
df1.columns
# Out:
# Index(['index', 'encounter_id', 'patient_id', 'race', 'gender', 'age',
#        'weight', 'time_in_hospital', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'diag_4', 'diag_5', 'number_diagnoses', 'X1', 'X2', 'X3', 'X4', 'X5',
#        'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16',
#        'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23', 'X24', 'X25', 'change',
#        'diabetesMed'],
#       dtype='object')

# %%
df1=df1.drop(['index','patient_id','weight','medical_specialty'],axis=1)

# %%
df1.shape
# Out:
# (16647, 44)

# %%
ot_columns=['time_in_hospital','num_lab_procedures','num_procedures','num_medications','number_outpatient',
           'number_emergency','number_inpatient','diag_5','number_diagnoses']

# %%
for col in ot_columns:

    q1=np.percentile(df1[col],25) 
    q3=np.percentile(df1[col],75)

    IQR=q3-q1
    
    print('Outliers for :',col,'\n')
    print(q1,q3,IQR)

#detecting upper bounds
    upper=q3+1.5*IQR
    print('Upper',upper)

    up=df1[col]>=upper
    print(np.where(up))


#detectiong lower bounds
    lower=q1-1.5*IQR
    print('lower',lower)

    lw=df1[col]<=lower
    print(np.where(lw),'\n')
# Out:
# Outliers for : time_in_hospital
#
# 2.0 6.0 4.0
# Upper 12.0
# (array([   20,    24,   201,   202,   223,   331,   399,   443,   457,
#          463,   470,   489,   494,   496,   525,   534,   572,   587,
#          591,   646,   650,   672,   679,   700,   722,   724,   757,
#          771,   823,   842,   914,   925,   933,   936,   947,   948,
#          991,  1017,  1022,  1045,  1077,  1155,  1172,  1178,  1197,
#         1228,  1292,  1294,  1323,  1327,  1340,  1353,  1380,  1411,
#         1470,  1496,  1504,  1540,  1560,  1564,  1567,  1837,  1873,
#         1889,  1927,  1943,  1980,  1991,  1993,  1996,  2010,  2097,
#         2113,  2140,  2141,  2163,  2174,  2280,  2291,  2345,  2360,
#         2368,  2445,  2460,  2474,  2480,  2500,  2511,  2536,  2541,
#         2592,  2649,  2746,  2823,  2862,  2900,  2918,  2965,  2969,
#         2982,  2993,  2997,  3040,  3044,  3116,  3125,  3128,  3152,
#         3174,  3228,  3238,  3239,  3261,  3266,  3299,  3321,  3356,
#         3370,  3470,  3497,  3565,  3567,  3583,  3634,  3641,  3662,
#         3697,  3700,  3703,  3712,  3744,  3802,  3830,  3841,  3851,
#         3874,  3880,  3886,  3907,  3931,  3996,  4006,  4075,  4113,
#         4135,  4151,  4189,  4316,  4334,  4355,  4366,  4372,  4407,
#         4472,  4478,  4545,  4550,  4585,  4600,  4608,  4673,  4835,
#         4862,  4940,  5010,  5037,  5043,  5106,  5141,  5205,  5262,
#         5273,  5298,  5332,  5340,  5344,  5367,  5407,  5431,  5499,
#         5541,  5550,  5615,  5704,  5716,  5737,  5823,  5883,  5893,
#         5915,  5985,  5989,  5993,  5994,  6002,  6003,  6033,  6034,
#         6142,  6156,  6211,  6229,  6243,  6254,  6272,  6305,  6372,
#         6381,  6387,  6439,  6441,  6455,  6490,  6582,  6597,  6625,
#         6629,  6631,  6645,  6689,  6702,  6703,  6704,  6709,  6713,
#        13452, 13485, 13533, 13534, 13576, 13606, 13629, 13690, 13696,
#        13748, 13771, 13791, 13822, 13838, 13854, 13898, 13901, 13943,
#        13961, 13972, 14046, 14063, 14121, 14133, 14142, 14221, 14237,
#        14263, 14272, 14369, 14455, 14473, 14481, 14495, 14642, 14652,
#        14767, 14857, 14885, 14904, 14909, 14957, 14974, 15022, 15081,
#        15104, 15121, 15136, 15202, 15222, 15236, 15247, 15318, 15328,
#        15330, 15353, 15406, 15438, 15464, 15499, 15501, 15516, 15549,
#        15577, 15662, 15692, 15727, 15747, 15828, 15836, 15837, 15853,
#        15895, 15898, 15945, 15988, 15996, 16031, 16043, 16104, 16149,
#        16165, 16188, 16198, 16199, 16205, 16336, 16337, 16366, 16374,
#        16441, 16455, 16505, 16608], dtype=int64),)
# lower -5.0
# (array([], dtype=int64),)
#
# Outliers for : number_outpatient
#
# 0.0 0.0 0.0
# Upper 0.0
# (array([    0,     1,     2, ..., 16644, 16645, 16646], dtype=int64),)
# lower 0.0
# (array([    0,     2,     3, ..., 16643, 16644, 16645], dtype=int64),)
#
# Outliers for : number_emergency
#
# 0.0 0.0 0.0
# Upper 0.0
# (array([    0,     1,     2, ..., 16644, 16645, 16646], dtype=int64),)
# lower 0.0
# (array([    0,     1,     2, ..., 16644, 16645, 16646], dtype=int64),)
#
# Outliers for : number_inpatient
#
# 0.0 1.0 1.0
# Upper 2.5
# (array([    9,    41,    50, ..., 16591, 16610, 16630], dtype=int64),)
# lower -1.5
# (array([], dtype=int64),)
#
# Outliers for : diag_5
#
# 25.491496772207654 75.35529174073125 49.86379496852359
# Upper 150.15098419351665
# (array([], dtype=int64),)
# lower -49.304195680577735
# (array([], dtype=int64),)
#
# Outliers for : number_diagnoses
#
# 6.0 9.0 3.0
# Upper 13.5
# (array([ 1431,  2508,  3238,  5342,  5589,  6722,  9330, 10977, 11438,
#        11593, 12723], dtype=int64),)
# lower 1.5
# (array([   90,   381,   530,   539,   662,  1003,  1922,  2289,  2408,
#         4120,  4283,  4468,  5336,  5526,  5759,  5811,  6823,  7123,
#         7135,  7661,  7696,  9833,  9993, 10089, 10692, 10705, 11873,
#        12017, 12285, 13181, 13435, 13578, 13586, 13762, 14524, 14684,
#        15163, 15417, 15537, 15778, 16522], dtype=int64),)

# %%
out_columns=['time_in_hospital','num_lab_procedures','num_procedures','num_medications','number_diagnoses']

# %%
for col in out_columns:
    tenth_percentile=np.percentile(df1[col],10)
    ninetieth_percentile=np.percentile(df1[col],90)
    print(tenth_percentile,ninetieth_percentile)
    df1[col]=np.where(df1[col]<tenth_percentile,tenth_percentile,df1[col]) 
    df1[col]=np.where(df1[col]>ninetieth_percentile,ninetieth_percentile,df1[col])
# Out:
# 1.0 9.0
# 14.0 67.0
# 0.0 4.0
# 7.0 26.0
# 5.0 9.0

# %%
cat_col=['race','gender','age','diag_1','diag_2','diag_3','diag_4','X1', 'X2',
       'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11', 'X12', 'X13',
       'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21', 'X22', 'X23',
       'X24', 'X25', 'change', 'diabetesMed']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in cat_col:
    df1[col]= le.fit_transform(df1[col])

# %%
df1.shape
# Out:
# (16647, 44)

# %%
df1.to_csv('test2.csv')
